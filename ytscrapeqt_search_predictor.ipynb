# %% [markdown]
# <h1 style='font-family: "SF Atarian System";'>ytscrapeqt.py</h1>

# %% [markdown]
# <h3>A YouTube Transcript scraping program and it's associated MariaDB / MySQL database:</h3>
# <h2 style="font-family: 'SF Atarian System';"><b>ytscrape@192.168.1.250:3306</b></h2>

# %% [markdown]
# <p>The following Jupyter Notebook concerns the research and development of the associated database and creating utilities through Jupyter Notebooks, PHP and Python3 PyQt5 to manage and utilize that database</p>

# %%
###
# This is a JuPyTer Notebook for `ytscrapedb` a database created and grown by `ytscrapeqt` a python3 based
# Selenium WebDriver script & GUI, with shell based .LOG file. 
###

import os
import pymysql
import pandas as pd

host = os.getenv('MYSQL_HOST')
port = os.getenv('MYSQL_PORT')
user = os.getenv('MYSQL_USER')
password = os.getenv('MYSQL_PASSWORD')
database = os.getenv('MYSQL_DATABASE')

conn = pymysql.connect(
    host=host,
    port=int(3306),
    user="pyscrape",
    passwd="ytscrape",
    db="ytscrape",
    charset='utf8mb4')

###
# NOTE: This is the point at which MySQL / Python3 interaction bottlenecks the data used
#       After the first wildcard run in a channel with over 500 videos, a single set of data
#       is generated. The hypothesis of this experiment was that this data set of text, specifically
#       gathered from the titles, contains representative unique word tokens after proper data cleaning
#       (for this particular task) which can be used as a predictive search term list to effectively
#       scrape a large percentage of the videos in the channel.
#
# NOTE: Results. So far, the actual results are a bit more lean on unique scraping titles, but the concept
#       that keywords generated from an initial scrape can effectively cover the largest part of the entire
#       video set seems to be born out. The ratios for the first 10 words in the list yielded more than 50%
#       scrapes 7 out of 10 times. Some terms yielded small data sets (one was only 74 videos), and some
#       obviously resulted in a set of video title results which overlapped previously scraped video title
#       results, as seen by their larger number of skips than scrapes. These were marked in bold, italics and an
#       asterisk in the dev blog.
###


## This converts the entire MySQL Transcripts table into a DataFrame
#df = pd.read_sql_query("SELECT * FROM Transcripts WHERE `Channel Name` = 'theoria apophasis'", conn)
df = pd.read_sql_query("SELECT * FROM Transcripts WHERE `Channel Name` = 'khan academy'", conn)
df
# Out:
#       idTranscripts                                    Video URL  \
# 0              7666  https://www.youtube.com/watch?v=rf8FX2sI3gU
# 1              7667  https://www.youtube.com/watch?v=bcCLKACsYJ0
# 2              7668  https://www.youtube.com/watch?v=Hmwvj9X4GNY
# 3              7669  https://www.youtube.com/watch?v=KABB4Kr7WhU
# 4              7670  https://www.youtube.com/watch?v=p5mXv39n9GM
# ...             ...                                          ...
# 5088          12754  https://www.youtube.com/watch?v=IcmAxkEImtI
# 5089          12755  https://www.youtube.com/watch?v=bbeWLtarzrE
# 5090          12756  https://www.youtube.com/watch?v=poGjjX_VNbM
# 5091          12757  https://www.youtube.com/watch?v=hypi8QPsFEk
# 5092          12758  https://www.youtube.com/watch?v=TjOlZr_2uW4
#
#                                             Video Title  \
# 0     LearnStorm Growth Mindset: The Truth About You...
# 1             Adding fractions with unlike denominators
# 2                                       Parts of a cell
# 3     Parent Quick-Start Tips: For Kids Ages 12 and ...
# 4     Crystalline and amorphous polymers | AP Chemis...
# ...                                                 ...
# 5088        Rounding to the nearest tenth and hundredth
# 5089  Sum of squares of polynomial roots | Math for ...
# 5090  Visually subtracting fractions with unlike den...
# 5091         Interesting Polynomial Coefficient Problem
# 5092            Pythagorean theorem with right triangle
#
#                                       Video Description  \
# 0     Explore growth mindset with Thinky Pinky as he...
# 1             Adding fractions with unlike denominators
# 2     Parts of a cell: nucleus, ribosomes, endoplasm...
# 3     This video gives a quick overview of how paren...
# 4     Polymers can exist as both crystalline and amo...
# ...                                                 ...
# 5088        Rounding to the nearest tenth and hundredth
# 5089  Sum of Squares of Polynomial Roots (Newton Sum...
# 5090  Visually subtracting fractions with unlike den...
# 5091  Finding the coefficients of a third degree pol...
# 5092            Pythagorean theorem with right triangle
#
#                                        Video Transcript  Channel Name
# 0     - [Instructor] So this is your brain, say hi. ...  khan academy
# 1     - [Voiceover] Let's say that we have the fract...  khan academy
# 2     Let's talk a little bit about the structure of...  khan academy
# 3     - [Lauren] I'm Lauren from Khan Academy, and t...  khan academy
# 4     - [Instructor] Let's talk a little bit about c...  khan academy
# ...                                                 ...           ...
# 5088  - [Instructor] Joey used 0.432 pounds of chees...  khan academy
# 5089  In the last video, we figured out how to figur...  khan academy
# 5090  - Let's see if we can figure out with 3/4 minu...  khan academy
# 5091  I've been sent is pretty interesting algebra p...  khan academy
# 5092  - [Instructor] We're asked to find the value o...  khan academy
#
# [5093 rows x 6 columns]

# %% [markdown]
# <p style='font-family: "SF Atarian System"; font-size: 22px;'>This is a markdown cell... Here HTML and CSS can be used to organize and style text. The cells above and below are 'code' cells.</p>

# %% [markdown]
# <h3>Step One is to Query the Database: </h3>
# <h2>ytscrape@192.168.1.250:3306</h2>
# <p>The table we want is called <b>Transcripts</b></p>
# <p><b>Transcripts</b> (<i>or <b>ytscrape.Transcripts</b> in project namespace</i>), is described by 5 columns:
#     <ol>
#         <li>`idTranscripts`</li>
#         <li><i><b>`Video Title`</b></i></li>
#         <li>`Video URL`</li>
#         <li>`Channel Name`</li>
#         <li><i><b>`Video Description`</b></i></li>
#         <li><i><b>`Video Transcript`</b></i></li>
#     </ol>
# </p>
# <p>Columns marked in bold italic are fulltext indexed and can accept Queries using fulltext index search functionality; e.g. using "MATCH(`Column Name`) AGAINST('search term')" syntax</p>

# %%
## The Query Syntax is df = pd.read_sql_query("SQL QUERY", conn)

# %% [markdown]
# <p>A list of dataframes can be made, each one the result of a query to Transcripts or even a cross table query</p>
# <p>The nested queries using <b>set</b> logic, e.g. "WHERE `Column Name` IN( ... )" can be applied here, using search inputs and other parameters drawn from the user or the filesystem or devices or scrapes</p>

# %% [markdown]
# <p>The following line outputs the length of the rows in the dataframe from the SQL query sent to ytscrape.Transcripts above</p>

# %%
print(len(df))
# Out:
# 5093

# %% [markdown]
# <p>The following script pulls all the unique word tokens from a set of all the titles present in the original query result dataframe from above: <b>df</b>.</p>
# <h2 style="font-family: 'SF Atarian System';">HYPOTHESIS: </h2>
# <h3 style="font-family: 'SF Atarian System';">These words, when ranked for number of occurences can help to cut the total set of searchable videos differently, for example in the 500 result limited set returned experimentally from YouTube</h3>

# %%
## regular expressions for niave text processing, TIP use '\w+'
import re
#from nltk.corpus import stopwords
import nltk
nltk.download('stopwords')

# create stopwords from nltk library
stop_words = set(stopwords.words('english'))
## how to use stopwords on a string
## https://stackoverflow.com/questions/5486337/how-to-remove-stop-words-using-nltk-or-python
#filtered_words = [word for word in word_list if word not in stopwords.words('english')]
## NOTE: for the word list stage

# remove emojis with re
titles = ""
for i in range(0, len(df)):
    ## concatenate to string
    titles = titles + " " + df.loc[i][2]
    
## Removes anything between colons    
titles = re.sub("\:.*?\:"," ",titles)
## All Test to lowercase
titles = titles.lower()

## Clean up the numbers
titles = re.sub('\w\d\w', ' ', titles)
titles = re.sub('\d', ' ', titles)

## Clean up the symbols. Punctuation, special characters, other alphabets / languages
## NOTE the words face and with form the most frequent tokens after cleaning, adding them here as stop words
## They are actually generated by demoji, its the emoji descriptions text from that python library
titles = titles.translate(str().maketrans({
    "'" : " ",    "." : " ",    "," : " ",    '"' : ' ',    "!" : " ",    "?" : " ",    "`" : " ",    ":" : " ",
    "(" : " ",    ")" : " ",    "-" : " ",    "\\" : " ",    "/" : " ",    "~" : " ",    "…" : " ",    "$" : " ",
    "*" : " ",    "=" : " ",    "&" : " ",    "#" : " ",    "@" : " ",    "%" : " ",    "^" : " ",    "_" : " ",
    "+" : " ",    "{" : " ",    "}" : " ",    "[" : " ",    "]" : " ",    "|" : " ",    "<" : " ",    ">" : " ",
    ";" : " ",    "‘" : " ",    "’" : " ",    "€" : " ",    "“" : " ",    "”" : " ",    "ε" : " ",    "ὐ" : " ",
    "δ" : " ",    "α" : " ",    "ι" : " ",    "μ" : " ",    "改" : " ",    "善" : " ",    "σ" : " ",    "τ" : " ",
    "ή" : " ",    "☽" : " ",    "○" : " ",    "☾" : " ",    "ἐ" : " ",    "π" : " ",    "η" : " ",    "γ" : " ",
    "ν" : " ",    "ῶ" : " ",    "ö" : " ",    "ς" : " ",    "ü" : " ",    "ž" : " "
}))

## Additional Considerations: These tokens entered as utf8mb4 valid with mycursor.execute() function
## 改, 善, ☽, ○, ☾, ε, ὐ, δ, α, ι, μ, ο, ν, ί, α, σ, τ, ή, ἐ, π, η, ö, ς, ü, ž

###
# NOTE: Past here it is tokenized
###
titles_tokens = titles.split()
#print(titles_tokens)

## remove stopwords
#filtered_words = [word for word in word_list if word not in stopwords.words('english')]
titles_tokens = [word for word in titles_tokens if word not in stopwords.words('english')]

## Construct new list with no 1 or 2  or N letter words
N = 3
titles_large_tokens = []
for word_token in titles_tokens:
    if len(word_token) > N:
        titles_large_tokens.append(word_token)

print("Length of titles tokens: " + str(len(titles_large_tokens)))

## sort for unique tokens
unique_titles_tokens = list(set(titles_large_tokens))

print("Length of unique titles tokens: " + str(len(unique_titles_tokens)))
print(unique_titles_tokens)
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /home/sparkone/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# Length of titles tokens: 17660
# Length of unique titles tokens: 2696
# ['takeaways', 'ways', 'bias', 'exams', 'claims', 'equilateral', 'motivating', 'orbitals', 'neutral', 'germany', 'structure', 'fertilization', 'july', 'carrying', 'parties', 'alignment', 'categorical', 'marc', 'markets', 'shoe', 'brazil', 'aspen', 'islam', 'projection', 'executive', 'surface', 'discontinuity', 'lottery', 'enthalpy', 'cumulative', 'extraneous', 'figurative', 'efficiency', 'frequency', 'civil', 'decreasing', 'conservation', 'looking', 'tony', 'versus', 'sampling', 'limeys', 'balances', 'citizenship', 'units', 'congressional', 'imbalance', 'wasserman', 'relativity', 'kite', 'elasticity', 'order', 'intersecting', 'brooke', 'rotating', 'maximum', 'cellular', 'molecular', 'haitian', 'criterion', 'prey', 'story', 'reactions', 'gaps', 'hall', 'differentiable', 'plessy', 'crime', 'franklins', 'dispersion', 'leveraging', 'polymers', 'externalities', 'cars', 'rules', 'dipoles', 'presidency', 'parametrizing', 'circumcenter', 'epoxide', 'early', 'signs', 'literary', 'regression', 'thermodynamics', 'origin', 'constitution', 'nonlinear', 'engineering', 'colonies', 'properties', 'unbiased', 'assessing', 'stories', 'guided', 'nprs', 'development', 'format', 'yards', 'chat', 'frequently', 'thoughts', 'iras', 'usain', 'floor', 'photosynthesis', 'bitcoin', 'within', 'rotaion', 'deficits', 'greco', 'livestream', 'contact', 'columbia', 'anatomy', 'skydiving', 'camp', 'columbus', 'transform', 'solved', 'eduardo', 'weaknesses', 'heatlh', 'journey', 'critical', 'separation', 'integer', 'respect', 'developing', 'houston', 'voter', 'austerity', 'buildings', 'rigid', 'tenth', 'states', 'effect', 'sound', 'tolls', 'squeeze', 'electrostatics', 'stages', 'block', 'vitamins', 'angela', 'poem', 'angular', 'internet', 'determine', 'funds', 'disk', 'academy', 'opbs', 'bases', 'commons', 'establishes', 'five', 'branch', 'connotation', 'sort', 'infections', 'variable', 'inferences', 'persian', 'yuen', 'arabia', 'civics', 'years', 'efficient', 'partial', 'nuclear', 'tert', 'jeff', 'december', 'consumption', 'modulus', 'invention', 'universe', 'chromatography', 'squared', 'arctan', 'gives', 'live', 'hypertonic', 'cauchy', 'cholesterol', 'graphically', 'policymaking', 'closures', 'galaxies', 'culture', 'differentiating', 'planning', 'volume', 'point', 'reconstruction', 'eulers', 'paulo', 'static', 'reading', 'adequacy', 'period', 'factoring', 'planes', 'freezing', 'grow', 'change', 'anova', 'numbers', 'wires', 'pearsons', 'double', 'divergence', 'claudia', 'kernel', 'confused', 'power', 'percentage', 'adjectives', 'unbalanced', 'drawings', 'height', 'resilience', 'slope', 'histograms', 'discussion', 'conditions', 'reagans', 'interpret', 'candidates', 'exclamations', 'remainder', 'actual', 'susan', 'connecting', 'parametrization', 'classical', 'vaporization', 'crisis', 'cabin', 'visually', 'image', 'elements', 'solve', 'nikole', 'truth', 'state', 'viewpoints', 'ellipse', 'still', 'difference', 'cards', 'lily', 'president', 'earmarks', 'dropbox', 'hundred', 'fareed', 'harder', 'sean', 'equitable', 'khan', 'index', 'corey', 'leonhardt', 'justifying', 'oxidation', 'green', 'sugar', 'templar', 'matter', 'greens', 'constructing', 'advantage', 'registered', 'carthage', 'benzene', 'bond', 'spectrum', 'influencing', 'constructions', 'punic', 'people', 'titles', 'cyrus', 'clusters', 'greek', 'independent', 'doubles', 'novel', 'population', 'possessive', 'decimal', 'neck', 'normative', 'insertion', 'acid', 'plan', 'potential', 'subject', 'groups', 'colors', 'redox', 'integrals', 'eigenvalues', 'hunt', 'drama', 'pattani', 'symmetries', 'compound', 'geographic', 'latin', 'first', 'specific', 'persians', 'rounding', 'hours', 'exponent', 'epoxides', 'integrating', 'career', 'yoga', 'switched', 'voltage', 'dilution', 'upcoming', 'thinking', 'telling', 'hiking', 'estate', 'flips', 'fico', 'salinas', 'defined', 'unadopted', 'ideal', 'four', 'murrayl', 'denser', 'confucianism', 'pairs', 'surplus', 'proper', 'obligations', 'samples', 'personal', 'physical', 'clarifying' ...

# %% [markdown]
# <p style="font-family: 'SF Atarian System';">
# For each of the preceeding unique terms, which is a set of pretty clean word tokens in which each element is unique. The original corpus had multiple occurrences of many words, meaning that for each of the elements in the reduced set of unique cleaned tokens, the original document has a frequency count for each of at least 1.
# </p>

# %% [markdown]
# <h4>It is interesting to note that the symbols
#     <ul>
#         <li>改</li>
#         <li>善</li>
#         <li>☽</li>
#         <li>○</li>
#         <li>☾</li>
#     </ul>
#     Did not cause an error with MariaDB's utf8mb4 character set encoding as they were pulled from <b>ytscrape.Transcripts</b>
# </h4>

# %% [markdown]
# <p>Additionally, eliminating two-character and possibly three-character words should shorten the list even further</p>

# %%
unique_titles_ranks = []
for word in unique_titles_tokens:
    word_count = 0
    for rawword in titles_large_tokens:
        if rawword == word:
            word_count += 1
    unique_titles_ranks.append(word_count)

# %%
###
# From: https://stackoverflow.com/questions/27488446/how-do-i-get-word-frequency-in-a-corpus-using-scikit-learn-countvectorizer
###
import numpy as np
from sklearn.feature_extraction.text import CountVectorizer

cv = CountVectorizer()
cv_fit = cv.fit_transform(titles_large_tokens)
print(cv.vocabulary_)
# Out:
# {'learnstorm': 1386, 'growth': 1078, 'mindset': 1574, 'kids': 1346, 'ages': 40, 'crystalline': 564, 'amorphous': 71, 'polymers': 1882, 'chemistry': 355, 'khan': 1342, 'academy': 2, 'grow': 1076, 'brain': 242, 'circles': 373, 'using': 2583, 'ideal': 1170, 'calculate': 272, 'number': 1699, 'moles': 1611, 'general': 1009, 'multiplication': 1640, 'rule': 2144, 'example': 862, 'measuring': 1536, 'enthalpy': 808, 'reaction': 2020, 'coffee': 410, 'calorimetry': 278, 'probability': 1936, 'permutations': 1826, 'combinations': 423, 'oxidation': 1758, 'numbers': 1700, 'identify': 1173, 'reduction': 2045, 'political': 1876, 'rights': 2115, 'citizenship': 382, 'high': 1121, 'school': 2177, 'civics': 384, 'kinetics': 1351, 'radioactive': 2004, 'decay': 605, 'choosing': 367, 'cards': 296, 'combinatorics': 424, 'interpreting': 1262, 'parallelogram': 1772, 'vector': 2600, 'addition': 27, 'vectors': 2601, 'precalculus': 1905, 'quadratic': 1986, 'systems': 2417, 'balancing': 170, 'simple': 2253, 'redox': 2042, 'equation': 820, 'chemical': 352, 'reactions': 2021, 'mexican': 1560, 'american': 68, 'history': 1133, 'mixtures': 1598, 'partial': 1785, 'pressures': 1924, 'limits': 1428, 'composite': 449, 'functions': 992, 'calculating': 273, 'concentration': 459, 'beer': 191, 'lambert': 1366, 'intro': 1272, 'determinant': 652, 'notation': 1689, 'computation': 455, 'matrices': 1512, 'free': 980, 'response': 2092, 'question': 1993, 'macroeconomics': 1470, 'geometric': 1019, 'series': 2216, 'convergence': 518, 'divergence': 714, 'examples': 863, 'simpsons': 2258, 'index': 1207, 'diversity': 716, 'ecology': 746, 'biology': 213, 'logistic': 1452, 'model': 1602, 'word': 2668, 'problem': 1937, 'differential': 676, 'equations': 821, 'calculus': 276, 'hasan': 1101, 'minhaj': 1576, 'finding': 930, 'gifts': 1030, 'authentic': 155, 'understanding': 2563, 'homeroom': 1139, 'dividing': 718, 'line': 1431, 'segments': 2198, 'according': 8, 'ratio': 2014, 'incorporating': 1199, 'opposing': 1726, 'viewpoints': 2617, 'reading': 2024, 'analyzing': 76, 'tone': 2496, 'choice': 365, 'graphing': 1058, 'given': 1033, 'point': 1868, 'slope': 2275, 'linear': 1432, 'graphs': 1059, 'algebra': 48, 'course': 545, 'mastery': 1506, 'tips': 2488, 'students': 2369, 'factors': 898, 'affecting': 36, 'rates': 2012, 'character': 340, 'change': 336, 'affects': 37, 'readers': 2023, 'civic': 383, 'engagement': 800, 'function': 990, 'symmetry': 2410, 'introduction': 1274, 'transformations': 2515, 'messages': 1553, 'morals': 1626, 'groups': 1075, 'influencing': 1231, 'policy': 1874, 'outcomes': 1751, 'government': 1049, 'politics': 1879, 'alkane': 53, 'isopropyl': 1302, 'group': 1073, 'organic': 1740, 'human': 1152, 'impacts': 1186, 'ecosystems': 750, 'interactions': 1250, 'shifts': 2232, 'demand': 629, 'labor': 1363, 'microeconomics': 1562, 'volume': 2630, 'pyramids': 1982, 'intuition': 1275, 'solid': 2283, 'geometry': 1020, 'physical': 1838, 'changes': 338, 'summarizing': 2388, 'stories': 2358, 'official': 1717, 'practice': 1901, 'impact': 1185, 'trophic': 2545, 'worked': 2671, 'lewis': 1409, 'diagram': 665, 'cyanide': 579, 'inequalities': 1218, 'solve': 2287, 'problems': 1938, 'solving': 2291, 'elements': 776, 'atoms': 148, 'subatomic': 2373, 'particles': 1787, 'immigration': 1184, 'migration': 1571, 'gilded': 1031, 'period': 1822, 'shrinking': 2240, 'performing': 1820, 'electronic': 770, 'transitions': 2517, 'energy': 797, 'drama': 728, 'area': 118, 'density': 638, 'court': 546, 'action': 17, 'magnus': 1476, 'carlsen': 300, 'friday': 985, 'march': 1494, 'mirror': 1586, 'optics': 1728, 'physics': 1839, 'satya': 2160, 'nadella': 1654, 'journey': 1327, 'becoming': 189, 'microsofts': 1564, 'reimagining': 2054, 'technologys': 2444, 'multiple': 1638, 'accounts': 10, 'topic': 2501, 'mosaic': 1628, 'plots': 1863, 'segmented': 2197, 'charts': 344, 'exploring': 880, 'variable': 2595, 'data': 593, 'statistics': 2342, 'text': 2463, 'main': 1477, 'ideas': 1172, 'types': 2553, 'intermolecular': 1258, 'for ...

# %%
## Further down the post
word_list = cv.get_feature_names()
count_list = cv_fit.toarray().sum(axis=0)    
word_count = dict(zip(word_list,count_list))
print(word_count)
# Out:
# {'absolute': 19, 'acaddemy': 1, 'academy': 1880, 'academys': 3, 'accelerates': 1, 'accelerating': 1, 'acceleration': 7, 'accepted': 1, 'according': 1, 'accounting': 1, 'accounts': 2, 'accretion': 1, 'accumulation': 8, 'achaemenid': 1, 'acid': 6, 'acids': 11, 'across': 3, 'action': 2, 'active': 1, 'activism': 1, 'actual': 1, 'acyl': 1, 'acylation': 2, 'adam': 1, 'added': 1, 'addendum': 1, 'adding': 15, 'addition': 16, 'address': 1, 'adequacy': 1, 'adjective': 1, 'adjectives': 2, 'adjusted': 1, 'advanced': 7, 'advantage': 5, 'affect': 1, 'affecting': 2, 'affects': 2, 'affinity': 1, 'affixes': 1, 'ages': 3, 'aggregate': 3, 'agreement': 2, 'aime': 4, 'airbus': 1, 'alcohol': 1, 'alcohols': 1, 'aldol': 1, 'algebra': 510, 'algebraic': 17, 'algebraically': 1, 'algorithm': 1, 'alignment': 1, 'alkane': 1, 'alkanes': 3, 'alkenes': 3, 'alkyl': 2, 'alkynes': 1, 'alligators': 1, 'almanac': 1, 'along': 1, 'alpha': 2, 'alternate': 7, 'alternating': 2, 'altos': 1, 'always': 1, 'amendment': 8, 'amendments': 3, 'american': 14, 'amides': 1, 'amino': 2, 'amorphous': 1, 'amplitude': 3, 'analysis': 6, 'analytic': 4, 'analyze': 2, 'analyzing': 14, 'anatomy': 3, 'ancient': 2, 'angela': 1, 'angle': 17, 'angled': 1, 'angles': 17, 'angular': 7, 'anhydrides': 1, 'anjali': 1, 'announcement': 6, 'annual': 1, 'another': 6, 'anova': 1, 'answer': 2, 'answers': 2, 'anti': 1, 'antiderivatives': 1, 'antietam': 1, 'anxiety': 3, 'anything': 11, 'apostles': 1, 'apostrophe': 2, 'appearance': 1, 'application': 5, 'applications': 10, 'applying': 24, 'appomattox': 1, 'appositives': 1, 'approach': 4, 'approaches': 1, 'approximate': 1, 'approximating': 3, 'approximation': 7, 'approximations': 1, 'april': 7, 'arabia': 2, 'arbitrage': 1, 'arccos': 1, 'arcs': 1, 'arcsin': 1, 'arctan': 1, 'area': 47, 'arent': 1, 'argand': 1, 'argon': 1, 'argument': 1, 'arguments': 1, 'arithmetic': 33, 'arizona': 1, 'arne': 1, 'aromatic': 3, 'around': 3, 'arrays': 1, 'arrhenius': 1, 'arthritis': 1, 'article': 9, 'articles': 2, 'ashoka': 1, 'asks': 2, 'aspen': 1, 'assassination': 1, 'assessing': 1, 'assignment': 1, 'associate': 1, 'associative': 2, 'astronauts': 1, 'astronomy': 5, 'asymptotes': 2, 'atherosclerosis': 1, 'atlantic': 1, 'atomic': 5, 'atoms': 1, 'attempts': 1, 'attitudes': 2, 'audio': 1, 'aufbau': 1, 'august': 6, 'austerity': 1, 'authentic': 2, 'average': 12, 'averages': 1, 'award': 1, 'axis': 8, 'aztec': 1, 'babylonians': 1, 'back': 2, 'background': 1, 'bacons': 1, 'bacteria': 1, 'bailout': 2, 'balance': 4, 'balanced': 1, 'balances': 2, 'balancing': 4, 'ball': 1, 'bang': 1, 'bank': 2, 'banking': 1, 'bankruptcy': 2, 'banks': 2, 'barbara': 1, 'barrel': 1, 'base': 7, 'based': 5, 'bases': 14, 'basic': 21, 'basics': 8, 'basis': 4, 'basketball': 1, 'bass': 1, 'beard': 1, 'becomes': 2, 'becoming': 2, 'bedside': 1, 'beer': 1, 'beginning': 1, 'beginnings': 2, 'behavior': 5, 'behind': 2, 'benefit': 1, 'benfords': 2, 'benjamin': 5, 'benzene': 1, 'berner': 1, 'bernoullis': 2, 'best': 9, 'better': 1, 'bhaskaras': 1, 'bialik': 1, 'bias': 1, 'bicycles': 1, 'bill': 8, 'binary': 3, 'binomial': 13, 'binomials': 3, 'biological': 1, 'biology': 42, 'biomolecules': 3, 'birmingham': 1, 'birthday': 1, 'bisector': 1, 'bisectors': 1, 'bitcoin': 2, 'bivariate': 2, 'black': 2, 'blackouttuesday': 1, 'block': 1, 'blocks': 1, 'blog': 1, 'blood': 2, 'blue': 2, 'board': 3, 'boards': 1, 'body': 2, 'boiling': 2, 'bolt': 1, 'boltzmann': 1, 'bond': 3, 'bonding': 3, 'bonds': 9, 'bonus': 1, 'borrowing': 1, 'bound': 2, 'boundaries': 1, 'bounds': 2, 'brain': 3, 'brainwave': 1, 'branch': 1, 'branches': 1, 'brandi': 1, 'brazil': 1, 'break': 1, 'breaking': 4, 'bring': 1, 'british': 1, 'brokaw': 1, 'brooke': 2, 'brown': 2, 'bryantt': 1, 'buffer': 2, 'buffers': 4, 'building': 3, 'buildings': 1, 'bully': 1, 'bunny': 1, 'bureaucracy': 2, 'bureaus': 1, 'business': 2, 'buying': 1, 'cabin': 1, 'cables': 1, 'caesar': 1, 'cahn': 1, 'cahsee': 1, 'calcuating': 1, 'calculate': 2, 'calculating': 17, 'calculations': 2, 'calculator': 6, ' ...

# %%
## This cell outputs the sorted list of words and word counts, largest to smallest
## Right away we can see that emoji descriptions contaminate the data
from operator import itemgetter
sorted_words = sorted(word_count.items(), key=itemgetter(1), reverse=True)
print(sorted_words)
# Out:
# [('khan', 1911), ('academy', 1880), ('algebra', 510), ('example', 246), ('calculus', 199), ('statistics', 192), ('equations', 174), ('functions', 167), ('probability', 166), ('linear', 156), ('introduction', 154), ('chemistry', 132), ('grade', 120), ('part', 113), ('geometry', 99), ('school', 95), ('math', 89), ('physics', 88), ('high', 81), ('worked', 79), ('rational', 76), ('history', 72), ('precalculus', 71), ('properties', 70), ('civics', 69), ('graphs', 69), ('homeroom', 69), ('government', 67), ('numbers', 66), ('examples', 65), ('expressions', 64), ('function', 61), ('microeconomics', 59), ('using', 59), ('word', 58), ('fractions', 57), ('problem', 57), ('finding', 55), ('derivative', 54), ('interpreting', 53), ('matrix', 48), ('area', 47), ('equation', 47), ('motion', 47), ('polynomial', 47), ('vectors', 47), ('line', 45), ('value', 45), ('differential', 44), ('biology', 42), ('trigonometry', 42), ('rule', 41), ('theorem', 41), ('variables', 41), ('data', 40), ('derivatives', 39), ('multivariable', 39), ('world', 39), ('quadratic', 38), ('reading', 38), ('solving', 38), ('systems', 38), ('matrices', 37), ('proof', 37), ('series', 37), ('transformations', 37), ('forces', 35), ('problems', 35), ('arithmetic', 33), ('decimals', 33), ('multiplying', 32), ('organic', 32), ('formula', 31), ('test', 31), ('capital', 30), ('markets', 30), ('trig', 29), ('change', 28), ('multiplication', 28), ('number', 28), ('vector', 28), ('comparing', 27), ('exponential', 27), ('finance', 27), ('free', 27), ('inequalities', 27), ('macroeconomics', 27), ('graph', 26), ('rules', 26), ('spaces', 26), ('volume', 26), ('exponent', 25), ('graphing', 25), ('applying', 24), ('complex', 24), ('constitution', 24), ('limits', 24), ('mathematics', 24), ('negative', 24), ('sample', 24), ('divergence', 23), ('response', 23), ('square', 23), ('dividing', 22), ('exercise', 22), ('identifying', 22), ('integral', 22), ('mean', 22), ('newtons', 22), ('property', 22), ('random', 22), ('regression', 22), ('basic', 21), ('division', 21), ('parts', 21), ('circle', 20), ('citizenship', 20), ('distribution', 20), ('factoring', 20), ('notation', 20), ('product', 20), ('slope', 20), ('sums', 20), ('triangle', 20), ('triangles', 20), ('unit', 20), ('absolute', 19), ('definite', 19), ('order', 19), ('ratios', 19), ('sections', 19), ('standard', 19), ('units', 19), ('form', 18), ('models', 18), ('table', 18), ('algebraic', 17), ('angle', 17), ('angles', 17), ('calculating', 17), ('chain', 17), ('constructing', 17), ('demand', 17), ('difference', 17), ('first', 17), ('geometric', 17), ('growth', 17), ('inverse', 17), ('modeling', 17), ('national', 17), ('polynomials', 17), ('subtracting', 17), ('thermodynamics', 17), ('time', 17), ('variable', 17), ('velocity', 17), ('addition', 16), ('conic', 16), ('economic', 16), ('equilibrium', 16), ('integrals', 16), ('laws', 16), ('naming', 16), ('rates', 16), ('special', 16), ('understanding', 16), ('whole', 16), ('adding', 15), ('combinatorics', 15), ('common', 15), ('curve', 15), ('distance', 15), ('early', 15), ('elasticity', 15), ('exponents', 15), ('force', 15), ('grammar', 15), ('learning', 15), ('life', 15), ('overview', 15), ('reasoning', 15), ('rights', 15), ('structure', 15), ('system', 15), ('wednesday', 15), ('american', 14), ('analyzing', 14), ('bases', 14), ('center', 14), ('distributions', 14), ('distributive', 14), ('model', 14), ('partial', 14), ('perimeter', 14), ('politics', 14), ('solutions', 14), ('binomial', 13), ('civil', 13), ('compound', 13), ('dimensional', 13), ('factor', 13), ('factors', 13), ('interval', 13), ('intro', 13), ('lines', 13), ('logarithms', 13), ('measuring', 13), ('points', 13), ('squares', 13), ('supply', 13), ('talks', 13), ('tangent', 13), ('average', 12), ('coordinates', 12), ('curl', 12), ('deviation', 12), ('find', 12), ('impact', 12), ('income', 12), ('interest', 12), ('intuition', 12), ('length', 12), ('marginal', 12), ('molecular', 12), ('period', 12), ('population', 12), ('propor ...

# %% [markdown]
# <h4 style="font-family: 'SF Atarian System';">The following cell generates a list, here of 32 elements, which should be sufficient to scrape a channel if used as predictive search terms, theoretically</h4>

# %%
## Let's see if we can get a top 22 list
top32_list = []
for i in range(0, 32):
    #print(sorted_words[i][0])
    top32_list.append(sorted_words[i][0])
print(top32_list)
## At 10 terms the rows collected were ~3300. At the same rate of efficiency another 10 or so should do it, 
## however, depending on whether these terms are related in a manner where one is to a large part a subset of
## another previously used term, or the aggregate terms collectively equivalate to such a set, the number of 
## successive scraping runs needed will be increased to beyond that number and be something which is dependent
## on that changing evaluation condition.
# Out:
# ['khan', 'academy', 'algebra', 'example', 'calculus', 'statistics', 'equations', 'functions', 'probability', 'linear', 'introduction', 'chemistry', 'grade', 'part', 'geometry', 'school', 'math', 'physics', 'high', 'worked', 'rational', 'history', 'precalculus', 'properties', 'civics', 'graphs', 'homeroom', 'government', 'numbers', 'examples', 'expressions', 'function']

# %% [markdown]
# <p style="font-family: 'SF Atarian System';">The following cell formats the text into a nice searchable clean string, the most basic form of this data</p>

# %%
import re
import string

# This is row 0, column 4 of dataframe. The first transcript in the table...
text = str(df.loc[0][4]).lower()

# This is a PyOhio regexp punctuation cleaning technique
text = re.sub('[%s]' % re.escape(string.punctuation), '', text)

print(text)
# Out:
# applause the standard household alkaline battery we use these every day all over the world but how do they work thats what well be covering in this video which is sponsored by squarespace head to squarespacecom to start your free trial or use code engineering mindset to save 10 on websites and domains a battery is a device used to store energy for a later point when we need it we use batteries to power small electrical devices such as a flashlight the energy is stored as chemical energy and this can be turned into electrical energy for when we need it if we look at a simple battery and lamp circuit to illuminate the lamp we need lots of electrons to flow through it the battery is going to provide the pushing force which allows electrons to flow through the lamp we simply need to connect the lamp across the positive and negative terminals of the battery to complete the circuit the battery can only push the electrons for a certain amount of time though this time depends on how much energy is stored inside the battery and how much is demanded by the load when we talk about load in an electrical circuit we mean any component which requires electricity to work these could be things such as resistors leds dc motors or even entire circuit boards some batteries can be recharged and it will clearly state this on the side of the battery but the typical household alkaline battery cant so this is simply disposed of when it runs out of energy these can be recycled though so do ensure you dispose of these responsibly by the way if you want to learn how a dc motor works then weve covered that in great detail previously do check that out links in the video description down below a typical 15 volt alkaline battery looks something like this but the colors will vary by manufacturer when we look at a battery we usually have a plastic wrapper fitted tightly to the outside this will insulate the battery but also tell us important information such as the capacity and the voltage as well as which end is positive and negative the positive end is known as the cathode and it will have this extended surface which protrudes outwards the negative end is known as the anode these two terminals are electrically isolated from each other under the wrapper we find the main casing which is usually made from steel with a nickel plating this holds all the internal components in place and stops them from interacting with elements of the atmosphere such as air and water within the casing we have multiple layers of different materials these materials are specially selected because their chemical reactions create certain levels of voltage and current the first layer is the anode which is a mixture of manganese oxide and graphite the graphite is added to improve the conductivity of the mixture and increases the energy density next we find a layer of porous material typically a fibrous paper which forms a barrier the barrier prevents the anode and cathode materials from having direct contact with each other this helps the battery last longer when its not being used if the barrier wasnt there then the battery would short circuit the microscopic holes within the material allows iron atoms to pass through it again well look at that in detail a little later in this video an electrolyte liquid of potassium hydroxide is then sprayed onto the separator during the manufacturing process this will soak it and it will be absorbed into the anode material the electrolyte used is an alkaline which is why we refer to this type of battery as an alkaline battery on the other side of the barrier we have an anode which is a paste made from zinc powder as well as a gelling agent the gelling agent just keeps the zinc suspended so it doesnt accumulate in one spot the zinc is in a powder form to increase the surface area of the material which lowers the internal resistance and thus improves electron transfer the steel capsule is sealed with a nylon plastic cap a brass pin is then inserted into ...

# %%
from sklearn.feature_extraction.text import CountVectorizer

cv = CountVectorizer(stop_words='english')
text_cv = cv.fit_transform(df)

# %%
# tokenize wtih split()
text_tokens = text.split()
print(text_tokens)
print(str(len(text_tokens)))
# Out:
# ['ladies', 'and', 'gentlemen', 'thank', 'you', 'for', 'coming', 'back', 'to', 'another', 'edition', 'of', 'tesla', 'vision', 'tv', 'we', 'are', 'going', 'to', 'review', 'some', 'work', 'of', 'a', 'very', 'special', 'individual', 'that', 'has', 'persevered', 'through', 'much', 'of', 'controversy', 'in', 'pursuit', 'of', 'technological', 'advancement', 'for', 'all', 'humankind', 'his', 'work', 'in', 'tesla', 'oriented', 'technologies', 'is', 'very', 'interesting', 'and', 'has', 'been', 'gaining', 'some', 'monumental', 'support', 'in', 'popular', 'culture', 'we', 'have', 'here', 'with', 'us', 'today', 'mr', 'eric', 'dollar', 'and', 'also', 'my', 'cohost', 'zoran', 'pilot', 'who', 'has', 'also', 'been', 'traveling', 'around', 'the', 'world', 'recently', 'and', 'has', 'been', 'meeting', 'with', 'various', 'organizations', 'at', 'the', 'tesla', 'museum', 'of', 'belgrade', 'and', 'educating', 'individuals', 'of', 'much', 'of', 'the', 'great', 'work', 'that', 'is', 'being', 'conducted', 'here', 'and', 'around', 'the', 'world', 'on', 'tesla', 'related', 'technologies', 'well', 'thank', 'you', 'sam', 'im', 'glad', 'to', 'be', 'back', 'and', 'im', 'glad', 'that', 'you', 'have', 'this', 'guest', 'because', 'as', 'you', 'know', 'i', 'live', 'in', 'california', 'and', 'im', 'very', 'much', 'fearless', 'person', 'but', 'to', 'be', 'honest', 'with', 'you', 'they', 'stick', 'to', 'work', 'very', 'hard', 'on', 'me', 'knowing', 'those', 'two', 'earthquakes', 'that', 'i', 'survived', 'here', 'and', 'its', 'a', 'northridge', 'and', 'whittier', 'and', 'i', 'really', 'appreciate', 'and', 'i', 'gonna', 'be', 'very', 'very', 'good', 'listener', 'what', 'eric', 'has', 'to', 'say', 'eric', 'welcome', 'to', 'the', 'show', 'thank', 'you', 'welcome', 'please', 'eric', 'if', 'you', 'will', 'tell', 'us', 'a', 'bit', 'about', 'your', 'recent', 'campaign', 'that', 'has', 'been', 'a', 'very', 'successful', 'well', 'i', 'mean', 'im', 'kind', 'of', 'at', 'a', 'distant', 'end', 'of', 'it', 'so', 'im', 'just', 'learning', 'about', 'a', 'lot', 'of', 'this', 'stuff', 'now', 'so', 'after', 'being', 'out', 'in', 'the', 'desert', 'and', 'its', 'fantastic', 'that', 'that', 'all', 'this', 'has', 'happened', 'because', 'we', 'really', 'faced', 'a', 'big', 'obstacle', 'of', 'having', 'to', 'come', 'up', 'with', 'the', 'bond', 'to', 'build', 'on', 'government', 'property', 'and', 'i', 'didnt', 'know', 'if', 'we', 'were', 'going', 'to', 'make', 'that', 'through', 'that', 'and', 'and', 'its', 'absolutely', 'fantastic', 'that', 'thats', 'happened', 'now', 'that', 'things', 'can', 'really', 'start', 'to', 'advance', 'wonderful', 'wonderful', 'now', 'ladies', 'and', 'gentlemen', 'for', 'listeners', 'mr', 'dollard', 'has', 'begun', 'a', 'project', 'to', 'make', 'an', 'advanced', 'seismic', 'warning', 'system', 'and', 'its', 'apparently', 'built', 'on', 'tesla', 'technology', 'would', 'you', 'please', 'enlighten', 'our', 'audience', 'a', 'bit', 'on', 'how', 'you', 'feel', 'that', 'this', 'seismic', 'warning', 'system', 'is', 'predicated', 'to', 'tesla', 'technology', 'well', 'actually', 'its', 'an', 'advancement', 'on', 'tech', 'tesla', 'technology', 'made', 'by', 'ernst', 'alexander', 'some', 'and', 'then', 'i', 'made', 'an', 'advancement', 'upon', 'that', 'in', 'order', 'to', 'make', 'it', 'a', 'wideband', 'system', 'where', 'you', 'werent', 'confined', 'to', 'one', 'resident', 'frequency', 'but', 'it', 'would', 'work', 'over', 'the', 'entire', 'audio', 'frequency', 'band', 'up', 'into', 'the', 'the', 'higher', 'end', 'of', 'the', 'vlf', 'part', 'that', 'only', 'like', 'coyotes', 'and', 'and', 'rats', 'can', 'hear', 'up', 'about', '250', 'kilocycles', 'and', 'that', 'basically', 'is', 'my', 'own', 'invention', 'took', 'about', '30', 'years', 'to', 'figure', 'it', 'out', 'from', 'an', 'analytical', 'standpoint', 'then', 'about', '10', 'years', 'the', 'antenna', 'wasnt', 'that', 'hard', 'to', 'build', 'other', 'than', 'finding', 'the', 'parts', 'but', 'it', 'took', '10', 'years', ' ...
# 7939

# %%
# now the text is tokenized. a unique word list can be made, where repeated words are mapped to one element of a
# basis set. 

###
# This method converts the list of word tokens into a set, then iterates over it into a list (f o g())
###
## Ref: https://www.freecodecamp.org/news/python-unique-list-how-to-get-all-the-unique-values-in-a-list-or-array/
unique_text_tokens = list(set(text_tokens))
print(unique_text_tokens)
print(str(len(unique_text_tokens)))
# Out:
# ['in', 'dealing', 'dead', 'spent', 'educating', 'loaded', 'skeleton', 'farnsworth', 'property', 'oneil', 'build', 'delivery', 'stupid', 'wrong', 'closer', 'latched', 'exponentially', '8', 'stuck', 'next', 'discoveries', 'say', 'practical', 'direction', 'since', 'horse', 'biography', 'grid', 'on', 'westinghouse', 'automobiles', 'existed', 'nine', '45', 'math', 'faster', 'pocket', 'significance', 'body', 'if', 'blow', 'requested', 'power', 'historical', 'banker', 'telephone', 'tower', 'whatever', 'writer', 'me', 'normal', 'named', 'thanking', 'occurred', 'school', 'difficult', 'indications', 'sciences', 'explain', 'phase', 'vandalized', 'story', 'clean', 'wherever', 'bit', 'conditions', 'pcom', 'monumental', 'erik', 'algebra', 'wireline', 'good', 'life', 'valley', 'technology', 'didnt', 'electrical', 'course', 'equations', 'gone', 'fullwidth', 'spooks', 'after', 'enlighten', 'plant', 'teslas', 'really', 'the', 'brilliant', 'pole', 'pursuing', 'human', 'pack', 'created', 'fortunate', 'part', 'made', 'like', 'united', 'fully', 'type', 'acclaimed', 'yet', 'except', 'tuning', 'crowd', 'follow', 'his', 'ever', 'um', 'advised', 'apparently', 'toyota', 'investigate', 'needed', 'bulb', 'tubes', 'biggest', 'definite', 'notes', 'traveling', 'few', 'involve', 'basis', 'kinds', 'opportunity', 'successful', 'before', 'also', 'as', 'celebration', 'imaginary', 'money', 'rise', 'enjoy', 'listener', 'funded', 'meet', 'popular', 'thousand', 'capable', '18', 'seven', 'dropped', 'massive', 'induction', 'resemble', 'afford', 'nikola', 'directed', 'anything', 'agency', 'couldnt', 'seen', 'impact', 'blaze', 'one', 'transmit', 'tehachapi', 'written', 'somewhere', 'bad', 'rats', 'i', 'squeeze', 'mankind', 'putting', 'somebodys', 'parents', 'ready', 'incredible', 'little', 'controversy', 'point', 'efforts', 'create', 'archaeological', 'plan', 'turned', 'cost', 'youve', 'expenses', 'cohost', 'involves', 'feinstein', 'science', 'ive', 'entire', 'paperwork', 'previously', 'analytically', 'versus', 'campaign', 'themselves', 'hold', 'back', 'eric', 'july', 'particularly', 'help', 'diane', 'facilities', 'building', 'save', 'rebuild', 'prediction', 'probably', 'order', 'hear', 'underway', 'landers', 'pen', 'out', 'between', 'disasters', 'statistics', 'basically', 'demonstrator', 'joke', 'term', 'thing', 'eldon', 'material', 'limit', 'frequencies', 'belgrade', 'yourself', 'enough', 'develop', 'operational', 'middle', 'im', 'light', 'just', 'experimental', 'support', 'geometry', 'engaged', 'beside', 'beautiful', 'mars', 'emp', 'become', 'possibility', 'university', 'call', 'certain', 'survey', 'fixing', 'figuring', 'electricity', 'weve', 'sen', 'for', 'clarify', 'alexander', 'desert', 'today', 'anderson', 'fifteen', '2000', 'particular', '10', 'wanted', 'sailors', 'portrayed', 'telluric', 'mainly', 'san', 'conducted', 'put', 'extent', 'transmitters', 'anywhere', 'advice', 'technological', 'representation', 'fault', 'son', 'wardenclyffe', 'studied', 'lie', 'billy', 'vision', 'constructed', 'propagation', 'theres', 'talking', 'fighting', 'wow', 'kind', 'primitive', 'glad', 'two', 'andreas', 'realized', 'come', 'doing', 'it', 'tomorrow', 'historically', 'hopelessness', 'deep', 'eight', 'abandoned', 'singular', 'some', 'wouldnt', 'sheer', 'system', 'reserve', 'operating', 'situation', 'proper', 'fortescue', 'currently', 'over', 'radio', 'polyface', 'creatures', 'magnet', 'tube', 'appear', 'happen', 'protected', 'corporation', 'fix', 'explained', 'honest', 'subject', 'war', 'crisis', 'seem', 'happened', 'coils', 'celebrate', 'form', 'breakthrough', 'forward', 'laid', 'is', 'advancement', 'donated', 'kilowatt', 'question', 'pursue', 'accumulated', 'squat', 'encouraging', 'normally', 'railroad', 'love', 'developed', 'involved', 'november', 'not', 'around', 'digging', 'area', 'go', '62', 'independence', 'instinct', 'went', 'audience', 'equipment', 'expected', 'diagram', 'started', 'everyones', 'please', 'generalized', 'pilot', 'private', 'there', 'obviously', 'sprouted', ...
# 1485

# %%
## Here we can see that there are only 1485 unique word tokens in this above transcript, so we can say the
## lexicon used is of 1485 words in size
