# %%
###
# This is a JuPyTer Notebook for `ytscrapedb` a database created and grown by `ytscrapeqt` a python3 based
# Selenium WebDriver script & GUI, with shell based 
###

import os
import pymysql
import pandas as pd

host = os.getenv('MYSQL_HOST')
port = os.getenv('MYSQL_PORT')
user = os.getenv('MYSQL_USER')
password = os.getenv('MYSQL_PASSWORD')
database = os.getenv('MYSQL_DATABASE')

conn = pymysql.connect(
    host=host,
    port=int(3306),
    user="pyscrape",
    passwd="ytscrape",
    db="ytscrape",
    charset='utf8mb4')

df = pd.read_sql_query("SELECT * FROM Transcripts", conn)
df.tail(10)
# Out:
#       idTranscripts                                    Video URL  \
# 6397           6398  https://www.youtube.com/watch?v=8zjdnQGhHfA
# 6398           6399  https://www.youtube.com/watch?v=s3Oy4ZO_cVA
# 6399           6400  https://www.youtube.com/watch?v=K2DsZUjNC5A
# 6400           6401  https://www.youtube.com/watch?v=PyJF2aUeglc
# 6401           6402  https://www.youtube.com/watch?v=167xYwhpXLk
# 6402           6403  https://www.youtube.com/watch?v=PDcUP5OJt6U
# 6403           6404  https://www.youtube.com/watch?v=CzWePy3dPeE
# 6404           6405  https://www.youtube.com/watch?v=tW-NSQoBJkQ
# 6405           6406  https://www.youtube.com/watch?v=XgBk97xfqWA
# 6406           6407  https://www.youtube.com/watch?v=SncwY6KVXkU
#
#                                             Video Title  \
# 6397  Angry Photographer: End of year synopsis, keep...
# 6398  PRIZES ALL ARRIVED FOR STREET PHOTO CONTEST…Ha...
# 6399  *!* OMG!! 3000 VIDEOS!!........ How did that h...
# 6400  Yeah, this picture stinks....but everyone is l...
# 6401  NO WAY!:flushed face::flushed face:OMG YES...l...
# 6402              Wireless TTL-AHOLICS. …needs VS wants
# 6403                     Ft. Myers Beach today shooting
# 6404                Yeah, dont do that in south Florida
# 6405  I WILL NEVER review a new lens with edited tes...
# 6406                         Fanboy-dom? Possibly maybe
#
#                                       Video Description  \
# 6397  Angry Photographer: End of year synopsis, keep...
# 6398        PRIZES ALL ARRIVED FOR STREET PHOTO CONTEST
# 6399  *!* OMG!! 3000 VIDEOS!!........ How did that h...
# 6400  Yeah, this picture stinks....but everyone is l...
# 6401  NO WAY!:flushed face::flushed face:OMG YES...l...
# 6402              Wireless TTL-AHOLICS. …needs VS wants
# 6403                                     No Description
# 6404                                     No Description
# 6405  I WILL NEVER review a new lens with edited tes...
# 6406                                     No Description
#
#                                        Video Transcript       Channel Name
# 6397  heyo what's that man how'd you like my my cere...  theoria apophasis
# 6398  okay all the prizes finally came in for the ph...  theoria apophasis
# 6399  oh my god how did I ever reach this point it s...  theoria apophasis
# 6400  be good mmm this picture socks I'm allowed to ...  theoria apophasis
# 6401  ah you know everybody saying I don't like it w...  theoria apophasis
# 6402  she trying to count the times I have ever thou...  theoria apophasis
# 6403                                            Skipped  theoria apophasis
# 6404  oh there's something I forgot to mention for y...  theoria apophasis
# 6405  I will never ever post images on a new lens or...  theoria apophasis
# 6406  boy is this a bit too fanboy yeah anyway not n...  theoria apophasis
